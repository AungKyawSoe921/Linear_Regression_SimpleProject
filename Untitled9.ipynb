# %% [markdown]
# <a href="https://colab.research.google.com/github/AungKyawSoe921/Linear_Regression_SimpleProject/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple Linear Regression Project

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Data

# %%
data = {'Hours': [1, 2, 3, 4, 5, 6],
        'Scores': [35, 40, 45, 50, 55, 60]}
df = pd.DataFrame(data)

# %% [markdown]
# Model

# %%
X = df[['Hours']]  #independent variable
Y = df['Scores']  #dependent variable
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# Visual

# %%
plt.scatter(X, Y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Hours vs Scores')
# Out:
# Text(0.5, 1.0, 'Hours vs Scores')
